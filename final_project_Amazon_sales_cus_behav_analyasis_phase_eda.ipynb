# %% [markdown]
# # ---------------------------------------------------------------------------

# %% [markdown]
# # Amazon Sales And Customer Behaviour Analysis

# %% [markdown]
# # -----------------------------------------------------------------------------

# %% [markdown]
# ###
# # 🛍️ Introduction
#
# ### In today’s fast-paced e-commerce environment, businesses need data-driven decisions to stay competitive.
# ### This project focuses on analyzing Amazon sales data to uncover valuable insights about customer behavior, product performance, and operational efficiency
#
# ### The dataset contains detailed information about:
# ### 	•	Orders – Order ID, Date, Status, Fulfillment, Sales Channel
# ### 	•	Products – Category, Style, SKU, Size
# ### 	•	Logistics – Ship Service Level, City, State, Postal Code
# ### •	Financials – Quantity, Currency, Amount
#
# ## 🎯 Objective
#
# ### The main goal of this analysis is to:
# ### 	•	Understand sales trends and seasonality
# ### 	•	Identify top-performing categories and products
# ### 	•	Detect cancellation/return patterns to improve fulfillment
# ### 	•	Explore customer purchase behavior to increase average order value
# ### 	•	Provide actionable recommendations to boost revenue and reduce losses
#
# #  Approach
# ### 	1.	Data Cleaning & Preprocessing
# ### 	•	Handled missing values, duplicates, and data type conversions
# ### 	2.	Exploratory Data Analysis (EDA)
# ### 	•	Conducted univariate, bivariate, and multivariate analysis
# ### 	•	Visualized trends using bar charts, pie charts, heatmaps, boxplots, and distributions
# ### 	3.	Insight Generation
# ### 	•	Derived business insights from data patterns
# ### 	•	Suggested strategies for growth and optimization
#
# ### This project aims to deliver practical, visually driven insights that help stakeholders make informed business decisions and optimize their sales strategy.

# %% [markdown]
# ## First step:

# %%
import pandas as pd

# %%
df=pd.read_csv(r"F:\final_ project_ dta_amazon\amazon data.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\4184842824.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"F:\final_ project_ dta_amazon\amazon data.csv")

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545  4/30/2022                     Cancelled
# 1      1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  4/30/2022                       Shipped
# 3      3  403-9615377-8133951  4/30/2022                     Cancelled
# 4      4  407-1069790-7240320  4/30/2022                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.tail()
# Out:
#          index             Order ID       Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  5/31/2022  Shipped     Amazon
# 128971  128971  402-9551604-7544318  5/31/2022  Shipped     Amazon
# 128972  128972  407-9547469-3152358  5/31/2022  Shipped     Amazon
# 128973  128973  402-6184140-0545956  5/31/2022  Shipped     Amazon
# 128974  128974  408-7436540-8728312  5/31/2022  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
print(df.shape)
# Out:
# (128975, 24)

# %%
print(df.columns)
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %% [markdown]
# # 2. Second step :Cleaning

# %% [markdown]
# ### 2.1 Check data quality

# %% [markdown]
# ### shape of data set

# %%
print("Rows:",df.shape[0],"Columns:",df.shape[1])
# Out:
# Rows: 128975 Columns: 24

# %% [markdown]
# ### Data types

# %%
print(df.dtypes)
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %% [markdown]
# ### missing values

# %%
print(df.isnull().sum())
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %% [markdown]
# ### summary stats

# %%
df.describe(include='all')
# Out:
#                 index             Order ID      Date   Status Fulfilment  \
# count   128975.000000               128975    128975   128975     128975
# unique            NaN               120378        91       13          2
# top               NaN  171-5057375-2831560  5/3/2022  Shipped     Amazon
# freq              NaN                   12      2085    77804      89698
# mean     64487.000000                  NaN       NaN      NaN        NaN
# std      37232.019822                  NaN       NaN      NaN        NaN
# min          0.000000                  NaN       NaN      NaN        NaN
# 25%      32243.500000                  NaN       NaN      NaN        NaN
# 50%      64487.000000                  NaN       NaN      NaN        NaN
# 75%      96730.500000                  NaN       NaN      NaN        NaN
# max     128974.000000                  NaN       NaN      NaN        NaN
#
#        Sales Channel  ship-service-level    Style           SKU Category  ...  \
# ...

# %% [markdown]
# ## 2.2 Handle missing values

# %%
# step 1 drop useless columns
df.drop(columns=['Unnamed: 22'],inplace=True)

# %%
# if more than 70% values missing, drop the coumn
threshold=0.7*len(df)
df=df.dropna(thresh=threshold,axis=1)

# %%
# step2: fill categorical columns
if 'Courier Status' in df.columns:
    df['Courier Status'].fillna("Unknown",inplace=True)
#for col in ['ship-city','ship-state','ship-postal-code','ship-country']:
    #if col in df.columns:
        #df[col].fillna("Not provided",inplace=True)
fill_values={
    "Shipcity":"Not provided",
    "Shipstate":"Not provided",
    "Shippostalcode":"Not provided",
    "Shipcountry":"Not provided"
}
df.fillna(value=fill_values,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\317907888.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Courier Status'].fillna("Unknown",inplace=True)

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545  4/30/2022                     Cancelled
# 1      1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  4/30/2022                       Shipped
# 3      3  403-9615377-8133951  4/30/2022                     Cancelled
# 4      4  407-1069790-7240320  4/30/2022                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ...        ASIN Courier Status Qty  currency  Amount  \
# ...

# %%
df.shape
# Out:
# (128975, 21)

# %%
# step 3 fill numeric columns
if 'Qty' in df.columns:
    df['Qty'].fillna(df['Qty'].median())

# %%
if 'currency' in df.columns:
    df['currency']=df['currency'].fillna(df['currency'].mode()[0])

# %%
df=df.dropna(subset=['Amount'])

# %%
df.shape
# Out:
# (121180, 21)

# %%
df.sample(10)
# Out:
#          index             Order ID       Date                        Status  \
# 50132    50132  407-9960534-5381143  5/31/2022                       Shipped
# 38181    38181  405-8086082-7603553   4/7/2022                       Shipped
# 86647    86647  408-2109845-3685105   5/3/2022  Shipped - Delivered to Buyer
# 25054    25054  402-1388095-8657111  4/15/2022                       Shipped
# 44933    44933  402-0190178-2497164   4/3/2022                       Shipped
# 125331  125331  403-1471614-0861127   6/3/2022  Shipped - Delivered to Buyer
# 116328  116328  402-7319867-3350760   6/9/2022  Shipped - Delivered to Buyer
# 39643    39643  405-7963726-2558718   4/6/2022  Shipped - Delivered to Buyer
# 27479    27479  171-1624713-0755522  4/14/2022                     Cancelled
# 76780    76780  171-8476780-6898725   5/9/2022  Shipped - Delivered to Buyer
#
#        Fulfilment Sales Channel  ship-service-level     Style  \
# ...

# %%
df['Amount']=df['Amount'].fillna(df['Amount'].median())

# %%
print(df.isnull().sum())
# Out:
# index                  0
# Order ID               0
# Date                   0
# Status                 0
# Fulfilment             0
# Sales Channel          0
# ship-service-level     0
# Style                  0
# SKU                    0
# Category               0
# Size                   0
# ASIN                   0
# Courier Status         0
# Qty                    0
# currency               0
# Amount                 0
# ship-city             31
# ship-state            31
# ship-postal-code      31
# ship-country          31
# B2B                    0
# dtype: int64

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.shape
# Out:
# (121180, 20)

# %% [markdown]
# # standardize to proper case

# %%
df.columns=df.columns.str.replace("-","")
df.columns=df.columns.str.replace("_","")
df.columns=df.columns.str.strip()
df.columns=df.columns.str.title()

# %% [markdown]
# ## fix common spelling issues

# %%
# fix common spelling issues
df.rename(columns={"Fulfilment":"Fulfillment"},inplace=True)

# %%
df.rename(columns={"Qty":"Quantity"},inplace=True)

# %%
df.head()
# Out:
#               Order Id       Date                        Status Fulfillment  \
# 0  405-8078784-5731545  4/30/2022                     Cancelled    Merchant
# 1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer    Merchant
# 2  404-0687676-7273146  4/30/2022                       Shipped      Amazon
# 3  403-9615377-8133951  4/30/2022                     Cancelled    Merchant
# 4  407-1069790-7240320  4/30/2022                       Shipped      Amazon
#
#   Sales Channel Shipservicelevel    Style              Sku       Category  \
# 0     Amazon.in         Standard   SET389   SET389-KR-NP-S            Set
# 1     Amazon.in         Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2     Amazon.in        Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3     Amazon.in         Standard    J0341       J0341-DR-L  Western Dress
# 4     Amazon.in        Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Order Id', 'Date', 'Status', 'Fulfillment', 'Sales Channel', 'Shipservicelevel', 'Style', 'Sku', 'Category', 'Size', 'Asin', 'Courier Status', 'Quantity', 'Currency', 'Amount', 'Shipcity', 'Shipstate', 'Shippostalcode', 'Shipcountry', 'B2B']

# %%
# Fill missing categorical values
fill_values = {
    'Shipcity': "Not Provided",
    'Shipstate': "Not Provided",
    'Shippostalcode': "Not Provided",
    'Shipcountry': "Not Provided",
    'Courier Status': "Unknown"
}

df.fillna(value=fill_values, inplace=True)

# Verify
print(df.isnull().sum())
# Out:
# Order Id            0
# Date                0
# Status              0
# Fulfillment         0
# Sales Channel       0
# Shipservicelevel    0
# Style               0
# Sku                 0
# Category            0
# Size                0
# Asin                0
# Courier Status      0
# Quantity            0
# Currency            0
# Amount              0
# Shipcity            0
# Shipstate           0
# Shippostalcode      0
# Shipcountry         0
# B2B                 0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Order Id            0
# Date                0
# Status              0
# Fulfillment         0
# Sales Channel       0
# Shipservicelevel    0
# Style               0
# Sku                 0
# Category            0
# Size                0
# Asin                0
# Courier Status      0
# Quantity            0
# Currency            0
# Amount              0
# Shipcity            0
# Shipstate           0
# Shippostalcode      0
# Shipcountry         0
# B2B                 0
# dtype: int64

# %% [markdown]
# ## handling duplicates

# %%
# count duplicate raws
df.duplicated().sum()
# Out:
# 3

# %%
# remove duplicates
df.drop_duplicates(subset=['Order Id'],keep='first',inplace=True)

# %%
 df.shape
# Out:
# (113030, 20)

# %% [markdown]
# ## Handle outliers in amount and quantity  most relevent in sales data

# %%
def count_outliers(series):
    q1=series.quantile(0.25)
    q3=series.quantile(0.75)
    iqr=q3-q1
    lower_limit=q1 - 1.5*iqr
    upper_limit=q3 + 1.5*iqr
    return((series<lower_limit)|(series>upper_limit)).sum()
amount_outliers=count_outliers(df['Amount'])
qty_outliers=count_outliers(df['Quantity'])
print("number of outliers in amount:",amount_outliers)
print("number of outliers in quantity:",qty_outliers)
# Out:
# number of outliers in amount: 3368
# number of outliers in quantity: 5054

# %% [markdown]
# # remove outliers

# %%
def remove_outliers_any(df, columns):
    df_out = df.copy()
    for col in columns:
        q1 = df_out[col].quantile(0.25)
        q3 = df_out[col].quantile(0.75)
        iqr = q3 - q1
        lower_limit = q1 - 1.5 * iqr
        upper_limit = q3 + 1.5 * iqr
        df_out = df_out[(df_out[col] > lower_limit) & (df_out[col] < upper_limit)]
    return df_out

df_clean = remove_outliers_any(df, ['Amount', 'Quantity'])

# %%
#print("number of outliers in amount:",amount_outliers)
#print("number of outliers in quantity:",qty_outliers)

# %%
amount_outliers_after = count_outliers(df_clean['Amount'])
qty_outliers_after = count_outliers(df_clean['Quantity'])
print("After cleaning - number of outliers in amount:", amount_outliers_after)
print("After cleaning - number of outliers in quantity:", qty_outliers_after)
# Out:
# After cleaning - number of outliers in amount: 0
# After cleaning - number of outliers in quantity: 0

# %% [markdown]
# ## Handle Datatypes

# %%
df.dtypes
# Out:
# Order Id             object
# Date                 object
# Status               object
# Fulfillment          object
# Sales Channel        object
# Shipservicelevel     object
# Style                object
# Sku                  object
# Category             object
# Size                 object
# Asin                 object
# Courier Status       object
# Quantity              int64
# Currency             object
# Amount              float64
# Shipcity             object
# Shipstate            object
# Shippostalcode       object
# Shipcountry          object
# B2B                    bool
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'],errors='coerce')

# %%
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')

# %%
cat_cols = ['Status', 'Fulfillment', 'Courier Statu', 'Shipcity', 'Shipstate', 'Shipcountry']

for col in cat_cols:
    if col in df.columns:
        df[col] = df[col].astype('category')

# %%
df['Order Id'] = df['Order Id'].astype(str)

# %%
df.dtypes
# Out:
# Order Id                    object
# Date                datetime64[ns]
# Status                    category
# Fulfillment               category
# Sales Channel               object
# Shipservicelevel            object
# Style                       object
# Sku                         object
# Category                    object
# Size                        object
# Asin                        object
# Courier Status              object
# Quantity                     int64
# Currency                    object
# Amount                     float64
# Shipcity                  category
# Shipstate                 category
# Shippostalcode              object
# Shipcountry               category
# B2B                           bool
# dtype: object

# %% [markdown]
# ## derived columns

# %% [markdown]
# ### Month and Year fom the date

# %%
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month
df['Month_Name']=df['Date'].dt.strftime('%B')

# %% [markdown]
# ### Total value per order

# %%
df['Total_value']=df['Quantity']*df['Amount']

# %% [markdown]
# ### order category

# %%
df['Order_category']=pd.cut(df['Total_value'],
                            bins=[0,100,500,float('inf')],
                            labels=['low','medium','high'])

# %% [markdown]
# ## Aggregation

# %% [markdown]
# ### Total sales by month

# %%
Monthly_sales=df.groupby(['Year','Month'])['Total_value'].sum().reset_index()

# %% [markdown]
# ### Average order value per cusomer/city

# %%
city_avg=df.groupby('Shipcity')['Total_value'].mean().reset_index()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\2092821307.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   city_avg=df.groupby('Shipcity')['Total_value'].mean().reset_index()

# %% [markdown]
# ### order per sales channel

# %%
channel_orders=df.groupby('Sales Channel')['Order Id'].nunique().reset_index()

# %% [markdown]
# ### category wise quantity sold

# %%
category_qty=df.groupby('Category')['Quantity'].sum().reset_index()

# %% [markdown]
# ## --------------------------------------------------------------------------

# %% [markdown]
# ### step 3 EDA + Visuals

# %% [markdown]
# ## ----------------------------------------------------------

# %%
 import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### set style

# %%
sns.set(style="whitegrid")

# %%
df.head()
# Out:
#               Order Id       Date                        Status Fulfillment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled    Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer    Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped      Amazon
# 3  403-9615377-8133951 2022-04-30                     Cancelled    Merchant
# 4  407-1069790-7240320 2022-04-30                       Shipped      Amazon
#
#   Sales Channel Shipservicelevel    Style              Sku       Category  \
# 0     Amazon.in         Standard   SET389   SET389-KR-NP-S            Set
# 1     Amazon.in         Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2     Amazon.in        Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3     Amazon.in         Standard    J0341       J0341-DR-L  Western Dress
# 4     Amazon.in        Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
# Univariate: Distribution of Sales Amount
plt.figure(figsize=(8,4))
sns.histplot(df['Amount'], bins=40, kde=True, color="teal")
plt.title("Distribution of Sales Amounts")
plt.xlabel("Order Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Univariate analysis: Most orders fall in to the low mid_value range,while very high orders are rare..This suggests bulk orders or premium items are less frequent,but they may contribute significantly to revanue")

# %%
# Univariate: Orders by Month (Seasonality)
monthly_orders = df['Month'].value_counts().sort_index()
monthly_orders.plot(kind='bar', figsize=(8,4), color="orange")
plt.title("Monthly Order Distribution")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.show()

# %% [markdown]
# ### Univariate analysis:Certain months show higher order volumes,pointing to seasonal demands(festivals,holidays,or promotions)..business can plan inventory,and marketing campaigns around these peak months

# %%
df['Status'].value_counts().plot(kind='bar', figsize=(7,4))
plt.title("Distribution of Order Status", fontsize=14)
plt.xlabel("Order Status")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 📦 Univariate Analysis: Order Status Distribution
# ### This bar chart shows how many orders are *Shipped, Cancelled, Refunded*, etc.
# ### It helps us understand the overall performance of the business.

# %%
df['Sales Channel'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title("Sales Channel Contribution", fontsize=14)
plt.ylabel("")
plt.show()

# %% [markdown]
# ### 🛍️ Univariate Analysis: Sales Channel Contribution
# ### This pie chart shows the percentage share of *Amazon.in, Amazon.com*, and other channels.

# %%
df['Category'].value_counts().head(10).plot(kind='barh', figsize=(8,5))
plt.title("Top 10 Best-Selling Categories", fontsize=14)
plt.xlabel("Number of Orders")
plt.ylabel("Category")
plt.show()

# %% [markdown]
# ### 🏆 Univariate Analysis: Top 10 Selling Categories
# ### This horizontal bar chart shows which product categories are the most popular.

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x=df['Quantity'])
plt.title("Distribution of Quantity Ordered", fontsize=14)
plt.xlabel("Quantity")
plt.show()

# %% [markdown]
# ### 📦 Univariate Analysis: Quantity Distribution
# ### A box plot to check if there are *outliers* in the quantity column (very large bulk orders).

# %%
# Bivariate: Top States by Sales
top_states = df.groupby('Shipstate')['Amount'].sum().sort_values(ascending=False).head(10)
top_states.plot(kind='bar', figsize=(10,5), color="skyblue")
plt.title("Top 10 States by Sales")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\3511742459.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_states = df.groupby('Shipstate')['Amount'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# ### Bivariate Analysis: A few states contribute the majority of sales,highlighting regional hotspots..these states are key markets where focused promotions or faster delivery logistics can boost growth

# %%
# Bivariate: Revenue by Fulfillment
plt.figure(figsize=(8,4))
sns.barplot(x='Fulfillment', y='Amount', data=df, estimator=sum,  palette="Set2")
plt.title("Revenue by Fulfillment Type")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\1652032015.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Fulfillment', y='Amount', data=df, estimator=sum,  palette="Set2")

# %% [markdown]
# ### Bivariate Analysis: "Revenue contribution differs significantly by fulfillment type... certain methods may be more profitable and efficient suggesting where the company should prioritize operations

# %%
df.groupby('Fulfillment')['Amount'].mean().plot(kind='bar', figsize=(7,4))
plt.title("Average Order Value by Fulfillment Type", fontsize=14)
plt.ylabel("Average Amount")
plt.xlabel("Fulfillment Type")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\3669826753.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Fulfillment')['Amount'].mean().plot(kind='bar', figsize=(7,4))

# %% [markdown]
# ### 🚚 Bivariate Analysis: Fulfillment Type vs Average Order Value
# ### Helps us see which fulfillment type , tends to have higher order values.

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(x='Quantity', y='Amount', data=df)
plt.title("Relationship between Quantity and Amount", fontsize=14)
plt.xlabel("Quantity")
plt.ylabel("Order Amount")
plt.show()

# %% [markdown]
# ### 📈 Bivariate Analysis: Quantity vs Amount
# ### Scatter plot shows whether higher quantities generally lead to higher order amounts.

# %%
df.groupby('Shipcountry')['Amount'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(8,4))
plt.title("Average Order Value by Shipping Country", fontsize=14)
plt.ylabel("Average Amount")
plt.xlabel("Shipping Country")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\2677691517.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Shipcountry')['Amount'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(8,4))

# %% [markdown]
# ### 🌍 Bivariate Analysis: Country-wise Average Order Value
# ### Shows which countries have higher-value purchases.

# %%
monthly_sales = df.groupby('Month')['Amount'].sum()
monthly_sales.plot(kind='line', marker='o', figsize=(8,4))
plt.title("Monthly Sales Trend", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.grid()
plt.show()

# %% [markdown]
# ### 📅 Bivariate Analysis: Monthly Sales Trend
# ### Shows how sales vary by month — helpful for identifying peak months and seasonal demand patterns.

# %%
# multivariate Pivot: Monthly Sales by Fulfillment
pivot1 = pd.pivot_table(df, values='Amount',
                        index=['Year','Month'],
                        columns='Fulfillment',
                        aggfunc='sum').fillna(0)
display(pivot1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\4081484843.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot1 = pd.pivot_table(df, values='Amount',
# Fulfillment      Amazon    Merchant
# Year Month
# 2022 3          81752.0    14219.85
#      4       18396443.0  8572164.66
#      5       16612685.0  7870421.32
#      6       15825266.0  6071386.50

# %%
# Multivariate: Monthly Sales by Fulfillment
pivot1 = pd.pivot_table(df, values='Amount',
                        index=['Year','Month'],
                        columns='Fulfillment',
                        aggfunc='sum').fillna(0)

pivot1.plot(kind='line', marker='o', figsize=(12,5))
plt.title("Monthly Sales Trend by Fulfillment Type")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\734364433.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot1 = pd.pivot_table(df, values='Amount',

# %% [markdown]
# ### Multivariate Analysis: sales trends show seasonal spikes and patterens vary by fulfilment type..This helps capacity planning for warehouses /logistics

# %%
# Multivariate: Average Order Value by Channel & B2B
pivot2 = pd.pivot_table(df, values='Amount',
                        index='Sales Channel',
                        columns='B2B',
                        aggfunc='mean').fillna(0)

pivot2.plot(kind='bar', figsize=(8,5), color=["salmon","lightgreen"])
plt.title("Average Order Value: Channel vs B2B")
plt.ylabel("Average Order Value")
plt.show()

# %% [markdown]
# ### Multivariate analysis: B2B orders consistantly have higher average order values than nonB2B.. sales channel also matters,this can guide channel specific pricing and promotions

# %% [markdown]
# ## Correlation using scatterplot

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Quantity'], df['Amount'], alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Amount')
plt.title('Quantity vs Amount (overall)')
plt.show()
print("Sales and quantity are positively related but pricing drives major differences")
# Out:
# Sales and quantity are positively related but pricing drives major differences

# %%
# ---------- Option 2: Quantity vs Amount by Category ----------
plt.figure(figsize=(8,6))
sns.scatterplot(x='Quantity', y='Amount', hue='Category', data=df, alpha=0.6)
plt.title("Quantity vs Amount by Category")
plt.show()

print("🔎 Insights - Quantity vs Amount by Category:")
print("- Different categories show different pricing behaviors.")
print("- Some categories achieve high sales with small quantities (premium products).")
print("- Categories with tight clusters indicate stable pricing.")
print("- Categories with wide spread show variable pricing across orders.")
# Out:
# 🔎 Insights - Quantity vs Amount by Category:
# - Different categories show different pricing behaviors.
# - Some categories achieve high sales with small quantities (premium products).
# - Categories with tight clusters indicate stable pricing.
# - Categories with wide spread show variable pricing across orders.

# %%
pivot = df.pivot_table(values='Amount', index='Fulfillment', columns='Status', aggfunc='sum', fill_value=0)
pivot.plot(kind='bar', figsize=(10,5))
plt.title("Sales Amount by Fulfillment Type and Order Status", fontsize=14)
plt.ylabel("Total Sales Amount")
plt.xlabel("Fulfillment Type")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14616\2529102531.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = df.pivot_table(values='Amount', index='Fulfillment', columns='Status', aggfunc='sum', fill_value=0)

# %% [markdown]
# ### 🔄 Multivariate Analysis: Fulfillment & Order Status vs Sales
# ### This pivot table chart combines *two categorical variables* (Fulfillment + Status) to show their combined effect on total sales.

# %%
# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features", fontsize=14)
plt.show()

# %% [markdown]
# ### 🔥 Multivariate Analysis: Correlation Heatmap
# ### This heatmap shows how numerical columns (like Amount, Quantity, Year) are correlated with each other.
# ### We can easily spot which variables have strong positive or negative relationships

# %% [markdown]
# # 📊 Final EDA Findings & Business Insights
# ## 🔑 Key Findings
# ### Sales Driven by Volume, Not Quantity
#
# ### Customers mostly purchase 1–3 items per order.
#
# ### High sales value comes from pricing and product category rather than bulk orders.
#
# ### Category Performance — “Kurta & Sets” Dominate
#
# ### Kurta & Sets are the revenue backbone with both high sales volume and premium orders.
#
# ### Dupatta, Blouse, Tops, Bottoms are low-value categories → act more as add-on products.
#
# ### Sarees & Western Wear underperform, suggesting niche demand or lack of promotion.
#
# ### Order Fulfillment & Status
#
# ### Majority of orders are successfully shipped via Amazon Fulfillment (FBA).
#
# ### Cancellations & returns are notable revenue leakages, often due to sizing or delivery issues.
#
# ### Merchant Fulfillment sales are very small → underutilized channel.
#
# ### Seasonality & Sales Trend
#
# ### Clear seasonal spike in April across both Amazon and Merchant fulfillment.
#
# ### Sales dip in later months, showing reliance on seasonal campaigns.
#
# ### Correlation Insights
#
# ### Order Amount and Total Value (0.85 correlation) → pricing is the key driver of revenue.
#
# ### Quantity and Total Value (0.49 correlation) → moderate impact, but weaker than pricing.
#
# ### B2B impact negligible → business is purely consumer-focused.
#
# ### 💡 Powerful Actionable Suggestions
# ### Boost Average Order Value (AOV)
#
# ### Launch bundle offers (Kurta + Dupatta, Set + Accessories).
#
# ### Promote premium versions of top categories to lift revenue without chasing bulk orders.
#
# ### Category Strategy
#
# ### Double down on Kurta & Sets (hero categories).
#
# ### Revive Sarees & Western Wear with targeted promotions, influencer campaigns, or festival tie-ins.
#
# ### Use low-value items (Dupatta, Blouse, Tops) as cross-sell add-ons or loyalty freebies.
#
# ### Reduce Returns & Cancellations
#
# ### Improve size guides, product descriptions, and delivery speed.
#
# ### Offer easy exchanges to reduce cancellations → retain customers instead of losing them.
#
# ### Diversify Fulfillment & Channels
#
# ### Scale Merchant Fulfillment for direct control over logistics and margins.
#
# ### Reduce 100% reliance on Amazon.in by expanding into Flipkart, Myntra, and own website.
#
# ### Seasonal Campaign & Inventory Planning
#
# ### Pre-stock & promote heavily during April-like seasonal spikes.
#
# ### Use flash sales & clearance offers in low-demand months to keep revenue stable.
#
# ### Align warehouse capacity with fulfillment type spikes (Amazon peaks need higher stock readiness).
#
# ### Customer Loyalty & Retention
#
# ### Introduce loyalty points, email reminders, and personalized recommendations.
#
# ### Target customers with abandoned carts and return history to convert missed sales.
#
# ## 🏁 Final Takeaway
# ### The business is volume-driven, with pricing and category choice as the real revenue levers.
#
# ### Kurta & Sets are the growth engines, while weaker categories need marketing revival.
#
# ### Seasonal spikes (April) highlight opportunities for strategic campaigns and capacity planning.
#
# ### Returns, cancellations, and platform dependency are the biggest risks to tackle.
#
# ### 👉 By raising AOV, diversifying sales channels, leveraging seasonal peaks, and reducing returns, the business can maximize revenue, reduce risks, and ensure long-term scalable growth.
